# %%
import pandas as pd
import numpy as np
import sqlite3

# %%
conn = sqlite3.connect('chembl_23\\chembl_23_sqlite\\chembl_23.db')

# %%
c = conn.cursor()

# %% [markdown]
# ## Table in the SQLite database

# %%
c.execute("SELECT name FROM sqlite_master WHERE type='table';")
for item in c.fetchall():
    print(item)
# Out:
# ('version',)
# ('chembl_id_lookup',)
# ('source',)
# ('docs',)
# ('research_stem',)
# ('structural_alert_sets',)
# ('bio_component_sequences',)
# ('molecule_dictionary',)
# ('research_companies',)
# ('structural_alerts',)
# ('compound_properties',)
# ('compound_records',)
# ('molecule_hierarchy',)
# ('molecule_synonyms',)
# ('biotherapeutics',)
# ('compound_structural_alerts',)
# ('compound_structures',)
# ('biotherapeutic_components',)
# ('target_type',)
# ('organism_class',)
# ('protein_family_classification',)
# ('protein_classification',)
# ('go_classification',)
# ('component_sequences',)
# ('variant_sequences',)
# ('target_dictionary',)
# ('component_class',)
# ('component_synonyms',)
# ('cell_dictionary',)
# ('protein_class_synonyms',)
# ('tissue_dictionary',)
# ('component_go',)
# ('target_components',)
# ('target_relations',)
# ('domains',)
# ('component_domains',)
# ('binding_sites',)
# ('site_components',)
# ('assay_type',)
# ('relationship_type',)
# ('confidence_score_lookup',)
# ('curation_lookup',)
# ('activity_stds_lookup',)
# ('data_validity_lookup',)
# ('bioassay_ontology',)
# ('parameter_type',)
# ('assays',)
# ('activities',)
# ('assay_parameters',)
# ('products',)
# ('atc_classification',)
# ('usan_stems',)
# ('hrac_classification',)
# ('irac_classification',)
# ('frac_classification',)
# ('patent_use_codes',)
# ('defined_daily_dose',)
# ('product_patents',)
# ('molecule_atc_classification',)
# ('molecule_irac_classification',)
# ('molecule_frac_classification',)
# ('molecule_hrac_classification',)
# ('formulations',)
# ('action_type',)
# ('drug_mechanism',)
# ('drug_indication',)
# ('ligand_eff',)
# ('predicted_binding_domains',)
# ('mechanism_refs',)
# ('indication_refs',)
# ('metabolism',)
# ('metabolism_refs',)
# ('sqlite_stat1',)

# %% [markdown]
# ## Columns in particular table

# %%
table_name = 'ACTIVITIES'
c.execute('PRAGMA TABLE_INFO({})'.format(table_name))

# collect names in a list
names = [tup[1] for tup in c.fetchall()]
print(names)
# Out:
# ['activity_id', 'assay_id', 'doc_id', 'record_id', 'molregno', 'standard_relation', 'published_value', 'published_units', 'standard_value', 'standard_units', 'standard_flag', 'standard_type', 'activity_comment', 'published_type', 'data_validity_comment', 'potential_duplicate', 'published_relation', 'pchembl_value', 'bao_endpoint', 'uo_units', 'qudt_units']

# %% [markdown]
# ## Count the structures as a function of SMILES code length

# %%
c.execute('select count(*) from (select molregno, canonical_smiles, length(canonical_smiles) from COMPOUND_STRUCTURES \
           where length(canonical_smiles) > 210)')
c.fetchmany(10)
# Out:
# [(18461,)]

# %% [markdown]
# ## Chosen query (takes all activities of type GI50 and IC50 where the activity values are not NULL)

# %%
columns = ['molregno', 'canonical_smiles', 'activity_id', 'published_value', 
           'published_units', 'standard_value', 'standard_units', 'standard_type', 'activity_comment']
c.execute("select CS.molregno, \
           CS.canonical_smiles, \
           AC.activity_id, \
           AC.published_value, \
           AC.published_units, \
           AC.standard_value, \
           AC.standard_units, \
           AC.standard_type, \
           AC.activity_comment \
           from COMPOUND_STRUCTURES CS \
           inner join ACTIVITIES AC on CS.molregno = AC.molregno \
           and (AC.standard_type = 'IC50' or AC.standard_type = 'GI50') \
           and (AC.standard_value IS NOT NULL or AC.published_value IS NOT NULL)")
#and AC.standard_units = 'M')")
#where CS.canonical_smiles = 'Cn1c(\C=C\c2ccc(cc2C(=O)O)C#N)cc3ccccc13' \
#where AC.standard_type = 'IC50' and AC.published_units = 'uM'")
#where AC.published_units = 'nM' and length(CS.canonical_smiles) > 210 \
#pd.DataFrame(c.fetchmany(1000), columns = columns)
DF_structures = pd.DataFrame(c.fetchall(), columns = columns)

# %%
DF_structures
# Out:
#          molregno                                   canonical_smiles  \
# 0          184040  COc1cc2C(=O)N(C)C3=C(\C(=C\CCCCl)\c4cc5OCOc5cc...
# 1          184040  COc1cc2C(=O)N(C)C3=C(\C(=C\CCCCl)\c4cc5OCOc5cc...
# 2          184040  COc1cc2C(=O)N(C)C3=C(\C(=C\CCCCl)\c4cc5OCOc5cc...
# 3          184040  COc1cc2C(=O)N(C)C3=C(\C(=C\CCCCl)\c4cc5OCOc5cc...
# 4          184040  COc1cc2C(=O)N(C)C3=C(\C(=C\CCCCl)\c4cc5OCOc5cc...
# 5          184040  COc1cc2C(=O)N(C)C3=C(\C(=C\CCCCl)\c4cc5OCOc5cc...
# 6          184040  COc1cc2C(=O)N(C)C3=C(\C(=C\CCCCl)\c4cc5OCOc5cc...
# 7          425503  C[C@@H]1[C@]2(O[C@H]3C=C4[C@@H]5CC[C@H]6Cc7nc8...
# 8          183969  COc1cc2C(=O)N(C)C3=C(\C(=C/CCCI)\c4cc5OCOc5cc3...
# 9          183969  COc1cc2C(=O)N(C)C3=C(\C(=C/CCCI)\c4cc5OCOc5cc3...
# 10         183969  COc1cc2C(=O)N(C)C3=C(\C(=C/CCCI)\c4cc5OCOc5cc3...
# 11         183969  COc1cc2C(=O)N(C)C3=C(\C(=C/CCCI)\c4cc5OCOc5cc3...
# 12         183969  COc1cc2C(=O)N(C)C3=C(\C(=C/CCCI)\c4cc5OCOc5cc3...
# 13         183969  COc1cc2C(=O)N(C)C3=C(\C(=C/CCCI)\c4cc5OCOc5cc3...
# 14         183969  COc1cc2C(=O)N(C)C3=C(\C(=C/CCCI)\c4cc5OCOc5cc3...
# 15         183969  COc1cc2C(=O)N(C)C3=C(\C(=C/CCCI)\c4cc5OCOc5cc3...
# 16          30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1
# 17          30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1
# 18          30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1
# 19          30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1
# 20          30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1
# 21          30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1
# 22          30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1
# 23          30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1
# 24          30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1
# 25          30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1
# 26          30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1
# 27          30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1
# 28          30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1
# 29          30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1
# ...           ...                                                ...
# 4122267   1972653  COC(=O)c1ccc(F)cc1NS(=O)(=O)c2cccc(c2)c3cnn(Cc...
# 4122268   1972654  CC(C)(C)OC(=O)N1CCN(CC1)c2nccc(n2)c3ccc(s3)c4c...
# 4122269   1530211  CC(C)(C)C(=O)N(CCCCCCN1C[C@H](O)[C@@H](O)[C@H]...
# 4122270   1972655  OC[C@H]1O[C@H](C(O)[C@H]1O)n2c3ccc(Cl)cc3c4c(n...
# 4122271   1357705  Clc1ccc(cc1)[C@@H]2[C@H](Oc3ccccc3)C(=O)N2CCn4...
# 4122272   1972653  COC(=O)c1ccc(F)cc1NS(=O)(=O)c2cccc(c2)c3cnn(Cc...
# 4122273   1972654  CC(C)(C)OC(=O)N1CCN(CC1)c2nccc(n2)c3ccc(s3)c4c...
# 4122274   1530211  CC(C)(C)C(=O)N(CCCCCCN1C[C@H](O)[C@@H](O)[C@H]...
# 4122275   1972655  OC[C@H]1O[C@H](C(O)[C@H]1O)n2c3ccc(Cl)cc3c4c(n...
# 4122276   1357705  Clc1ccc(cc1)[C@@H]2[C@H](Oc3ccccc3)C(=O)N2CCn4...
# 4122277   1972653  COC(=O)c1ccc(F)cc1NS(=O)(=O)c2cccc(c2)c3cnn(Cc...
# 4122278   1972654  CC(C)(C)OC(=O)N1CCN(CC1)c2nccc(n2)c3ccc(s3)c4c...
# 4122279   1530211  CC(C)(C)C(=O)N(CCCCCCN1C[C@H](O)[C@@H](O)[C@H]...
# 4122280   1972655  OC[C@H]1O[C@H](C(O)[C@H]1O)n2c3ccc(Cl)cc3c4c(n...
# 4122281   1357705  Clc1ccc(cc1)[C@@H]2[C@H](Oc3ccccc3)C(=O)N2CCn4...
# 4122282   1972653  COC(=O)c1ccc(F)cc1NS(=O)(=O)c2cccc(c2)c3cnn(Cc...
# 4122283   1972654  CC(C)(C)OC(=O)N1CCN(CC1)c2nccc(n2)c3ccc(s3)c4c...
# 4122284   1530211  CC(C)(C)C(=O)N(CCCCCCN1C[C@H](O)[C@@H](O)[C@H]...
# 4122285   1972655  OC[C@H]1O[C@H](C(O)[C@H]1O)n2c3ccc(Cl)cc3c4c(n...
# 4122286   1357705  Clc1ccc(cc1)[C@@H]2[C@H](Oc3ccccc3)C(=O)N2CCn4...
# 4122287   1972653  COC(=O)c1ccc(F)cc1NS(=O)(=O)c2cccc(c2)c3cnn(Cc...
# 4122288   1972654  CC(C)(C)OC(=O)N1CCN(CC1)c2nccc(n2)c3ccc(s3)c4c...
# 4122289   1530211  CC(C)(C)C(=O)N(CCCCCCN1C[C@H](O)[C@@H](O)[C@H]...
# 4122290   1972655  OC[C@H]1O[C@H](C(O)[C@H]1O)n2c3ccc(Cl)cc3c4c(n...
# 4122291   1357705  Clc1ccc(cc1)[C@@H]2[C@H](Oc3ccccc3)C(=O)N2CCn4...
# 4122292   1972653  COC(=O)c1ccc(F)cc1NS(=O)(=O)c2cccc(c2)c3cnn(Cc...
# 4122293   1972654  CC(C)(C)OC(=O)N1CCN(CC1)c2nccc(n2)c3ccc(s3)c4c...
# 4122294   1530211  CC(C)(C)C(=O)N(CCCCCCN1C[C@H](O)[C@@H](O)[C@H]...
# 4122295   1972655  OC[C@H]1O[C@H](C(O)[C@H]1O)n2c3ccc(Cl)cc3c4c(n...
# 4122296   1357705  Clc1ccc(cc1)[C@@H]2[C@H](Oc3ccccc3)C(=O)N2CCn4...
#
#          activity_id  published_value published_units  standard_value  \
# 0              35160     1.750000e+01              uM    1.750000e+04
# 1              35161     4.040000e+01              uM    4.040000e+04
# 2              35163     3.330000e+01              uM    3.330000e+04
# 3              35164     4.230000e+01              uM    4.230000e+04
# 4              35165     1.000000e+02              uM    1.000000e+05
# 5              35166     3.590000e+01              uM    3.590000e+04
# 6              35167     1.000000e+02              uM    1.000000e+05
# 7              35783     1.000000e+03              nM    1.000000e+03
# 8              36363     2.760000e+01              uM    2.760000e+04
# 9              36364     5.600000e-01              uM    5.600000e+02
# 10             36365     4.300000e+00              uM    4.300000e+03
# 11             36366     3.500000e+00              uM    3.500000e+03
# 12             36367     2.280000e+01              uM    2.280000e+04
# 13             36368     8.800000e+00              uM    8.800000e+03
# 14             36369     2.870000e+01              uM    2.870000e+04
# 15             36370     5.200000e+00              uM    5.200000e+03
# 16             38545     4.290000e-06               M    4.290000e+03
# 17             38546     3.050000e-06               M    3.050000e+03
# 18             38547     1.220000e-06               M    1.220000e+03
# 19             38548     3.530000e-06               M    3.530000e+03
# 20             38549     6.350000e-07               M    6.350000e+02
# 21             38550     5.060000e-05               M    5.060000e+04
# 22             38551     4.810000e-07               M    4.810000e+02
# 23             38552     1.730000e-07               M    1.730000e+02
# 24             38553     2.200000e-06               M    2.200000e+03
# 25             38554     2.380000e-06               M    2.380000e+03
# 26             38555     2.240000e+00               M    2.240000e+09
# 27             38556     4.170000e-06               M    4.170000e+03
# 28             38557     1.610000e-06               M    1.610000e+03
# 29             38558     5.810000e-06               M    5.810000e+03
# ...              ...              ...             ...             ...
# 4122267     16662873     5.000000e+00              uM    5.000000e+03
# 4122268     16662874     7.000000e+00              uM    7.000000e+03
# 4122269     16662875     7.000000e-02              uM    7.000000e+01
# 4122270     16662876     5.000000e+00              uM    5.000000e+03
# 4122271     16662877     3.000000e+00              uM    3.000000e+03
# 4122272     16662878     6.000000e+00              uM    6.000000e+03
# 4122273     16662879     7.000000e+00              uM    7.000000e+03
# 4122274     16662880     6.000000e-01              uM    6.000000e+02
# 4122275     16662881     7.000000e+00              uM    7.000000e+03
# 4122276     16662882     6.000000e+00              uM    6.000000e+03
# 4122277     16662883     1.000000e+01              uM    1.000000e+04
# 4122278     16662884     5.000000e+01              uM    5.000000e+04
# 4122279     16662885     2.000000e+00              uM    2.000000e+03
# 4122280     16662886     5.000000e+01              uM    5.000000e+04
# 4122281     16662887     3.000000e+00              uM    3.000000e+03
# 4122282     16662888     5.000000e+01              uM    5.000000e+04
# 4122283     16662889     2.000000e+00              uM    2.000000e+03
# 4122284     16662890     8.000000e-02              uM    8.000000e+01
# 4122285     16662891     3.000000e+00              uM    3.000000e+03
# 4122286     16662892     4.000000e+00              uM    4.000000e+03
# 4122287     16662893     5.000000e+01              uM    5.000000e+04
# 4122288     16662894     3.000000e+00              uM    3.000000e+03
# 4122289     16662895     2.000000e-01              uM    2.000000e+02
# 4122290     16662896     3.000000e+00              uM    3.000000e+03
# 4122291     16662897     2.000000e+00              uM    2.000000e+03
# 4122292     16662898     1.000000e+01              uM    1.000000e+04
# 4122293     16662899     1.000000e+01              uM    1.000000e+04
# 4122294     16662900     5.000000e+01              uM    5.000000e+04
# 4122295     16662901     5.000000e+01              uM    5.000000e+04
# 4122296     16662902     6.000000e+00              uM    6.000000e+03
#
#         standard_units standard_type activity_comment
# 0                   nM          GI50             None
# 1                   nM          GI50             None
# 2                   nM          GI50             None
# 3                   nM          GI50             None
# 4                   nM          GI50             None
# 5                   nM          GI50             None
# 6                   nM          GI50             None
# 7                   nM          GI50             None
# 8                   nM          GI50             None
# 9                   nM          GI50             None
# 10                  nM          GI50             None
# 11                  nM          GI50             None
# 12                  nM          GI50             None
# 13                  nM          GI50             None
# 14                  nM          GI50             None
# 15                  nM          GI50             None
# 16                  nM          GI50             None
# 17                  nM          GI50             None
# 18                  nM          GI50             None
# 19                  nM          GI50             None
# 20                  nM          GI50             None
# 21                  nM          GI50             None
# 22                  nM          GI50             None
# 23                  nM          GI50             None
# 24                  nM          GI50             None
# 25                  nM          GI50             None
# 26                  nM          GI50             None
# 27                  nM          GI50             None
# 28                  nM          GI50             None
# 29                  nM          GI50             None
# ...                ...           ...              ...
# 4122267             nM          IC50             None
# 4122268             nM          IC50             None
# 4122269             nM          IC50             None
# 4122270             nM          IC50             None
# 4122271             nM          IC50             None
# 4122272             nM          IC50             None
# 4122273             nM          IC50             None
# 4122274             nM          IC50             None
# 4122275             nM          IC50             None
# 4122276             nM          IC50             None
# 4122277             nM          IC50             None
# 4122278             nM          IC50             None
# 4122279             nM          IC50             None
# 4122280             nM          IC50             None
# 4122281             nM          IC50             None
# 4122282             nM          IC50             None
# 4122283             nM          IC50             None
# 4122284             nM          IC50             None
# 4122285             nM          IC50             None
# 4122286             nM          IC50             None
# 4122287             nM          IC50             None
# 4122288             nM          IC50             None
# 4122289             nM          IC50             None
# 4122290             nM          IC50             None
# 4122291             nM          IC50             None
# 4122292             nM          IC50             None
# 4122293             nM          IC50             None
# 4122294             nM          IC50             None
# 4122295             nM          IC50             None
# 4122296             nM          IC50             None
#
# [4122297 rows x 9 columns]

# %% [markdown]
# ### Store on file

# %%
DF_structures.to_csv('DF_GI50_IC50_all.csv', index = False)

# %%
DF_structures.head(50)
# Out:
#     molregno                                   canonical_smiles  activity_id  \
# 0     184040  COc1cc2C(=O)N(C)C3=C(\C(=C\CCCCl)\c4cc5OCOc5cc...        35160
# 1     184040  COc1cc2C(=O)N(C)C3=C(\C(=C\CCCCl)\c4cc5OCOc5cc...        35161
# 2     184040  COc1cc2C(=O)N(C)C3=C(\C(=C\CCCCl)\c4cc5OCOc5cc...        35163
# 3     184040  COc1cc2C(=O)N(C)C3=C(\C(=C\CCCCl)\c4cc5OCOc5cc...        35164
# 4     184040  COc1cc2C(=O)N(C)C3=C(\C(=C\CCCCl)\c4cc5OCOc5cc...        35165
# 5     184040  COc1cc2C(=O)N(C)C3=C(\C(=C\CCCCl)\c4cc5OCOc5cc...        35166
# 6     184040  COc1cc2C(=O)N(C)C3=C(\C(=C\CCCCl)\c4cc5OCOc5cc...        35167
# 7     425503  C[C@@H]1[C@]2(O[C@H]3C=C4[C@@H]5CC[C@H]6Cc7nc8...        35783
# 8     183969  COc1cc2C(=O)N(C)C3=C(\C(=C/CCCI)\c4cc5OCOc5cc3...        36363
# 9     183969  COc1cc2C(=O)N(C)C3=C(\C(=C/CCCI)\c4cc5OCOc5cc3...        36364
# 10    183969  COc1cc2C(=O)N(C)C3=C(\C(=C/CCCI)\c4cc5OCOc5cc3...        36365
# 11    183969  COc1cc2C(=O)N(C)C3=C(\C(=C/CCCI)\c4cc5OCOc5cc3...        36366
# 12    183969  COc1cc2C(=O)N(C)C3=C(\C(=C/CCCI)\c4cc5OCOc5cc3...        36367
# 13    183969  COc1cc2C(=O)N(C)C3=C(\C(=C/CCCI)\c4cc5OCOc5cc3...        36368
# 14    183969  COc1cc2C(=O)N(C)C3=C(\C(=C/CCCI)\c4cc5OCOc5cc3...        36369
# 15    183969  COc1cc2C(=O)N(C)C3=C(\C(=C/CCCI)\c4cc5OCOc5cc3...        36370
# 16     30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1        38545
# 17     30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1        38546
# 18     30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1        38547
# 19     30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1        38548
# 20     30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1        38549
# 21     30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1        38550
# 22     30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1        38551
# 23     30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1        38552
# 24     30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1        38553
# 25     30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1        38554
# 26     30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1        38555
# 27     30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1        38556
# 28     30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1        38557
# 29     30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1        38558
# 30     30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1        38559
# 31     30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1        38560
# 32     30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1        38561
# 33     30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1        38562
# 34     30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1        38563
# 35     30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1        38564
# 36     30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1        38565
# 37     30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1        38566
# 38     30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1        38567
# 39     30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1        38568
# 40     30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1        38569
# 41     30086            COc1ccc(NCc2cnc3nc(N)nc(N)c3c2C)c(OC)c1        38570
# 42     81029                  CC[S+]([O-])C(=O)N(O)c1ccc(Cl)cc1        38705
# 43     30075         COc1cc(OC)cc(c1)N(C)Cc2cnc3nc(N)nc(N)c3c2C        43265
# 44     30075         COc1cc(OC)cc(c1)N(C)Cc2cnc3nc(N)nc(N)c3c2C        43266
# 45     30075         COc1cc(OC)cc(c1)N(C)Cc2cnc3nc(N)nc(N)c3c2C        43267
# 46     30075         COc1cc(OC)cc(c1)N(C)Cc2cnc3nc(N)nc(N)c3c2C        43268
# 47     30075         COc1cc(OC)cc(c1)N(C)Cc2cnc3nc(N)nc(N)c3c2C        43269
# 48     30075         COc1cc(OC)cc(c1)N(C)Cc2cnc3nc(N)nc(N)c3c2C        43271
# 49     30075         COc1cc(OC)cc(c1)N(C)Cc2cnc3nc(N)nc(N)c3c2C        43272
#
#     published_value published_units  standard_value standard_units  \
# 0      1.750000e+01              uM    1.750000e+04             nM
# 1      4.040000e+01              uM    4.040000e+04             nM
# 2      3.330000e+01              uM    3.330000e+04             nM
# 3      4.230000e+01              uM    4.230000e+04             nM
# 4      1.000000e+02              uM    1.000000e+05             nM
# 5      3.590000e+01              uM    3.590000e+04             nM
# 6      1.000000e+02              uM    1.000000e+05             nM
# 7      1.000000e+03              nM    1.000000e+03             nM
# 8      2.760000e+01              uM    2.760000e+04             nM
# 9      5.600000e-01              uM    5.600000e+02             nM
# 10     4.300000e+00              uM    4.300000e+03             nM
# 11     3.500000e+00              uM    3.500000e+03             nM
# 12     2.280000e+01              uM    2.280000e+04             nM
# 13     8.800000e+00              uM    8.800000e+03             nM
# 14     2.870000e+01              uM    2.870000e+04             nM
# 15     5.200000e+00              uM    5.200000e+03             nM
# 16     4.290000e-06               M    4.290000e+03             nM
# 17     3.050000e-06               M    3.050000e+03             nM
# 18     1.220000e-06               M    1.220000e+03             nM
# 19     3.530000e-06               M    3.530000e+03             nM
# 20     6.350000e-07               M    6.350000e+02             nM
# 21     5.060000e-05               M    5.060000e+04             nM
# 22     4.810000e-07               M    4.810000e+02             nM
# 23     1.730000e-07               M    1.730000e+02             nM
# 24     2.200000e-06               M    2.200000e+03             nM
# 25     2.380000e-06               M    2.380000e+03             nM
# 26     2.240000e+00               M    2.240000e+09             nM
# 27     4.170000e-06               M    4.170000e+03             nM
# 28     1.610000e-06               M    1.610000e+03             nM
# 29     5.810000e-06               M    5.810000e+03             nM
# 30     3.350000e-06               M    3.350000e+03             nM
# 31     1.150000e-06               M    1.150000e+03             nM
# 32     1.000000e-04               M    1.000000e+05             nM
# 33     1.260000e-04               M    1.260000e+05             nM
# 34     6.270000e-06               M    6.270000e+03             nM
# 35     5.880000e-07               M    5.880000e+02             nM
# 36     2.890000e-06               M    2.890000e+03             nM
# 37     8.520000e-07               M    8.520000e+02             nM
# 38     2.830000e-06               M    2.830000e+03             nM
# 39     1.910000e-06               M    1.910000e+03             nM
# 40     3.530000e-06               M    3.530000e+03             nM
# 41     3.590000e-07               M    3.590000e+02             nM
# 42     5.000000e-01              uM    5.000000e+02             nM
# 43     5.360000e-07               M    5.360000e+02             nM
# 44     2.090000e-07               M    2.090000e+02             nM
# 45     7.420000e-07               M    7.420000e+02             nM
# 46     5.410000e-07               M    5.410000e+02             nM
# 47     4.420000e-07               M    4.420000e+02             nM
# 48     5.440000e-07               M    5.440000e+02             nM
# 49     4.100000e-07               M    4.100000e+02             nM
#
#    standard_type activity_comment
# 0           GI50             None
# 1           GI50             None
# 2           GI50             None
# 3           GI50             None
# 4           GI50             None
# 5           GI50             None
# 6           GI50             None
# 7           GI50             None
# 8           GI50             None
# 9           GI50             None
# 10          GI50             None
# 11          GI50             None
# 12          GI50             None
# 13          GI50             None
# 14          GI50             None
# 15          GI50             None
# 16          GI50             None
# 17          GI50             None
# 18          GI50             None
# 19          GI50             None
# 20          GI50             None
# 21          GI50             None
# 22          GI50             None
# 23          GI50             None
# 24          GI50             None
# 25          GI50             None
# 26          GI50             None
# 27          GI50             None
# 28          GI50             None
# 29          GI50             None
# 30          GI50             None
# 31          GI50             None
# 32          GI50             None
# 33          GI50             None
# 34          GI50             None
# 35          GI50             None
# 36          GI50             None
# 37          GI50             None
# 38          GI50             None
# 39          GI50             None
# 40          GI50             None
# 41          GI50             None
# 42          GI50             None
# 43          GI50             None
# 44          GI50             None
# 45          GI50             None
# 46          GI50             None
# 47          GI50             None
# 48          GI50             None
# 49          GI50             None

# %%
np.sum(~DF_structures.loc[:, 'standard_units'].isna())
# Out:
# 4121503

# %%
~DF_structures.loc[:, 'standard_units'].isna().values
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
DF_structures = DF_structures[~DF_structures.loc[:, 'standard_units'].isna()]

# %% [markdown]
# ### Groupby definition + aggregation functions

# %%
grouped = DF_structures.groupby('molregno')

# %%
aggFunctions = {
                'molregno': ['min', 'count'], 'canonical_smiles': 'min',
                'published_value': ['min', 'max', 'mean'],
                #'published_units': 'min',
                'standard_value': ['min', 'max', 'mean'],
                'standard_units': 'max',
                'standard_type': 'min',
                #'activity_comment': 'min'
                }

# %%
DF_structuresGrouped = grouped.agg(aggFunctions)

# %%
DF_structuresGrouped.tail(5)
# Out:
#          molregno                                         canonical_smiles  \
#               min count                                                min
# molregno
# 2096031   2096031     1  CC(CC(=O)C[C@](C)(O)[C@H]1CC(=O)[C@@]2(C)C3=C(...
# 2096032   2096032     2  C(Oc1ccc2[nH]nc(c3nc4cc(ccc4[nH]3)N5CCCCC5)c2c...
# 2096033   2096033     2  Clc1cnccc1COc2ccc3[nH]nc(c4nc5cc(ccc5[nH]4)N6C...
# 2096034   2096034     2  Clc1cncc(Cl)c1COc2ccc3[nH]nc(c4nc5cc(ccc5[nH]4...
# 2096152   2096152     7  COC(=O)CCc1c(C)c2cc3nc(cc4[nH]c(cc5nc(cc1[nH]2...
#
#          published_value                       standard_value           \
#                      min        max       mean            min      max
# molregno
# 2096031          21.3300    21.3300    21.3300        21330.0  21330.0
# 2096032          20.8000  5016.9000  2518.8500           20.8   5016.9
# 2096033          13.6000  3071.1000  1542.3500           13.6   3071.1
# 2096034           6.6000   158.7000    82.6500            6.6    158.7
# 2096152           3.5296     9.6205     5.6461         3529.6   9620.5
#
#                    standard_units standard_type
#               mean            max           min
# molregno
# 2096031   21330.00             nM          IC50
# 2096032    2518.85             nM          IC50
# 2096033    1542.35             nM          IC50
# 2096034      82.65             nM          IC50
# 2096152    5646.10             nM          IC50

# %%
DF_structuresGrouped.to_csv('DF_GI50_IC50_grouped_20180612.csv', index = False)

# %% [markdown]
# Same min and max, homogenous group of rows of active species

# %%
sameActivities = DF_structuresGrouped.loc[:, 'standard_value'].loc[:, 'min'] == DF_structuresGrouped.loc[:, 'standard_value'].loc[:, 'max']

# %%
DF_structuresGrouped = DF_structuresGrouped[sameActivities]

# %%
DF_structuresGrouped.to_csv('DF_GI50_IC50_grouped_20180612.csv', index = False)

# %% [markdown]
# ## Full query (multiple joins)

# %%
columns = ['molregno', 'canonical_smiles', 'alogp', 'aromatic_rings', 'full_mwt', 'activity_id', 'published_value', 
           'published_units', 'standard_value', 'standard_units', 'standard_type', 'DOC: title', 'ASSY: description']
c.execute("select min(canonical_smiles), min(standard_units), max(standard_value) from (select CS.molregno, \
           CS.canonical_smiles, \
           CP.alogp, \
           CP.aromatic_rings, \
           CP.full_mwt, \
           AC.activity_id, \
           AC.published_value, \
           AC.published_units, \
           AC.standard_value, \
           AC.standard_units, \
           AC.standard_type, \
           DO.title, \
           ASSY.description \
           from COMPOUND_STRUCTURES CS \
           inner join COMPOUND_PROPERTIES CP on CS.molregno = CP.molregno \
           inner join ACTIVITIES AC on CS.molregno = AC.molregno \
           inner join DOCS DO on AC.doc_id = DO.doc_id \
           inner join ASSAYS ASSY on AC.assay_id = ASSY.assay_id \
           where AC.published_units = 'uM'\
           group by CS.molregno)")
#where AC.standard_type = 'IC50' and AC.published_units = 'uM'")
pd.DataFrame(c.fetchmany(100))
#DF_IC50 = pd.DataFrame(c.fetchmany(1000), columns = columns)

# %%
DF_IC50['standard_value'] = DF_IC50['standard_value'].astype('float')
DF_IC50.loc[:, 'negLogIC'] = pd.Series( -1.0 * np.log10(DF_IC50['standard_value']), index = DF_IC50.index )

# %% [markdown]
# ## Get the units distribution of the ACTIVITY

# %%
c.execute("select min(standard_units), count(*) DESCENDING from ACTIVITIES group by standard_units")
#where AC.standard_type = 'IC50' and AC.published_units = 'uM'")
pd.DataFrame(c.fetchall(), columns = ['unit', 'count']).sort_values('count', ascending = False)
# Out:
#                             unit     count
# 1403                          nM  10051691
# 0                           None   1612336
# 1                              %   1512432
# 1992                     ug.mL-1    673717
# 1830                          uM     98469
# 1340                          mm     78990
# 977                           hr     58959
# 1973                     ug ml-1     58864
# 1181                     mg.kg-1     57280
# 1144                     mg kg-1     27610
# 1078               mL.min-1.kg-1     24517
# 935                            g     23729
# 839                   cells.uL-1     22703
# 879                    degrees C     21271
# 662                       IU.L-1     17649
# 1771                           s     15911
# 1071                     mEq.L-1     15582
# 1508                  ng.hr.mL-1     13332
# 1077                mL.min-1.g-1     12469
# 694                       L.kg-1     12287
# 2                         % ID/g     12052
# 869                          day     11416
# 1273                         min      9989
# 2055                   umol.kg-1      9791
# 796                        U.L-1      9406
# 1354                        mmHg      8510
# 1894                       uM.hr      6722
# 1084                          mM      6220
# 1925                       ucm/s      5895
# 1682                          pg      5320
# ...                          ...       ...
# 1177                   mg-1 kg-1         1
# 359                     10'1/s/M         1
# 1679                     pcm s-1         1
# 1142                mg g-1 day-1         1
# 1690                       pg/dl         1
# 1689                    pg.hr/ml         1
# 1150        mg kg-1 day-1 b.i.d.         1
# 47          (m equiv [Na+]) kg-1         1
# 46    (m equiv [Na+]) 5hr-1 kg-1         1
# 1685                     pg kg-1         1
# 761                          PbU         1
# 758                       PFU/ml         1
# 757                       Osm/kg         1
# 753                          Na2         1
# 750                       Monkey         1
# 351                    10'-9cm/s         1
# 1673                    pM/mg/hr         1
# 743                          MST         1
# 739                         M/uL         1
# 1678                          pS         1
# 733                          M-2         1
# 1910                 uM/hr/Kg/mg         1
# 1676                   pM/min/ml         1
# 355                   10'1 ug/ml         1
# 1675                   pM/min/mg         1
# 42         (equiv of [H+]) 2hr-1         1
# 358                       10'1/s         1
# 1674                pM/mg/minute         1
# 1918                  uN h kg/mg         1
# 1489                   ng hr g-1         1
#
# [2089 rows x 2 columns]

# %% [markdown]
# ## Get the activity type distribution

# %%
c.execute("select min(standard_type), count(*) DESCENDING from ACTIVITIES group by standard_type")
#where AC.standard_type = 'IC50' and AC.published_units = 'uM'")
pd.DataFrame(c.fetchall(), columns = ['type', 'count']).sort_values('count', ascending = False)
# Out:
#                              type    count
# 4279                      Potency  4598151
# 2057                         GI50  2569096
# 2349                         IC50  1820108
# 2520                   Inhibition   836240
# 316                      Activity   768774
# 2777                           Ki   648840
# 3330                          MIC   512481
# 1674                         EC50   358198
# 148                          AC50   156778
# 1734                         ED50    98633
# 4495                        Ratio    88447
# 2053                           GI    84790
# 2756                           Kd    83120
# 2449                           IZ    80931
# 4733            Residual Activity    73944
# 4508                   Ratio IC50    68728
# 5269        Tissue Severity Score    66533
# 812                          CC50    61371
# 5103                         T1/2    46551
# 2884                         LC50    42517
# 854                            CL    40473
# 5154                          TGI    37407
# 1615                  Drug uptake    33333
# 4957                   Solubility    29926
# 4511                     Ratio Ki    28617
# 1894                           FC    26617
# 3338                        MIC90    26447
# 3333                        MIC50    23835
# 214                           AUC    22831
# 1882                            F    19595
# ...                           ...      ...
# 4015                   P-450 loss        1
# 4012                   P Increase        1
# 5660             average log GI50        1
# 1294               Cures@ 20mg/kg        1
# 1295              Cures@ 40 mg/kg        1
# 1296               Cures@ 40mg/kg        1
# 1297              Cures@ 80 mg/kg        1
# 3886             No. of rats died        1
# 5640                       [Ca2+]        1
# 2424                           IN        1
# 5635       [3H] thymidinecpm/dish        1
# 3926                     No_cures        1
# 224   AUC glu reduction(mM x min)        1
# 2421                     ILSmaxOD        1
# 2413                    ILS (Sur)        1
# 1306             Cytocidal effect        1
# 2054                 GI clearence        1
# 234          AUC(0-24) normalised        1
# 3969                 Of viability        1
# 235                      AUC(app)        1
# 3977         Onset for sleep, min        1
# 237                       AUCED90        1
# 3982         Opsin shift activity        1
# 5596                Weight (mg/g)        1
# 2409                          ILA        1
# 5589                        WCC90        1
# 3990                    Oral dose        1
# 240                  AUClast/dose        1
# 2404      IFN gamma concentration        1
# 5607              Weight increase        1
#
# [6172 rows x 2 columns]

# %% [markdown]
# ## Column names

# %%
table_name = 'ASSAYS'
c.execute('PRAGMA TABLE_INFO({})'.format(table_name))

# collect names in a list
names = [tup[1] for tup in c.fetchall()]
print(names)
# Out:
# ['assay_id', 'doc_id', 'description', 'assay_type', 'assay_test_type', 'assay_category', 'assay_organism', 'assay_tax_id', 'assay_strain', 'assay_tissue', 'assay_cell_type', 'assay_subcellular_fraction', 'tid', 'relationship_type', 'confidence_score', 'curated_by', 'src_id', 'src_assay_id', 'chembl_id', 'cell_id', 'bao_format', 'tissue_id', 'variant_id']

# %%
table_name = 'ACTIVITIES'
c.execute('PRAGMA TABLE_INFO({})'.format(table_name))

# collect names in a list
names = [tup[1] for tup in c.fetchall()]
print(names)
# Out:
# ['activity_id', 'assay_id', 'doc_id', 'record_id', 'molregno', 'standard_relation', 'published_value', 'published_units', 'standard_value', 'standard_units', 'standard_flag', 'standard_type', 'activity_comment', 'published_type', 'data_validity_comment', 'potential_duplicate', 'published_relation', 'pchembl_value', 'bao_endpoint', 'uo_units', 'qudt_units']

# %%
conn.close()
