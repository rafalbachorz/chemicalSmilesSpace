# %%
import pickle
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# '/home/rafalb/work/molecules/chemicalSmilesSpace/src'

# %%
with open('../data/processed/molDataAfterAggAndCleaned.pickle', 'rb') as f:
    molData = pickle.load(f)

# %%
molData.columns
# Out:
# Index(['canonicalSmiles', 'negativeCharged', 'positiveCharged', 'elementsSet',
#        'numberOfRings', 'numberOfAtoms', 'activityMin', 'activityMax',
#        'activityType', 'alogP', 'molregIdx', 'molregCount', 'HBacceptors',
#        'HBdonors', 'polarSurface', 'rotatableBonds', 'RO3pass',
#        'nRO5violations', 'acidBaseNeutral', 'fullMolecularWeight',
#        'aromaticRings', 'numberOfHeavyAtoms', 'QEDweighted',
#        'canonicalSmilesLength', 'organicChemistryElementsOnly'],
#       dtype='object')

# %%
molData
# Out:
#                                              canonicalSmiles  negativeCharged  \
# molregIdx
# 10         c1cc2cc(c1)-c1cccc(c1)C[n+]1ccc(c3ccccc31)NCCC...              0.0
# 23                            O=C1OC(=CBr)CCC1c1cccc2ccccc12              0.0
# 24                             O=C1OC(=CI)CCC1c1cccc2ccccc12              0.0
# 25                         C#CC=C1CCC(c2cccc3ccccc23)C(=O)O1              0.0
# 31         COc1cc2nc(N3CCN(C(=O)C4CC4c4ccccc4)CC3)nc(N)c2...              0.0
# ...                                                      ...              ...
# 2341548    FC(F)(F)Oc1ccc2nc(-c3ccc(OCCOCCOc4ccc(-c5nc6cc...              0.0
# 2341612    Cc1sc2c(c1C)C(c1ccc(Cl)cc1)=NC(CC(=O)NCCCCCCCC...              0.0
# 2341613    COc1cc2c(c(OC)n1)C1(O)C(O)C(CN(C)C)C(c3ccccc3)...              0.0
# 2341615    C=CC(C)CC1NC(=O)C(CC(C)C)N(C)C(=O)C(C)N(C)C(=O...              0.0
# 2341617    COC1CCC=Cc2cccc(c2)C(CCNC(=O)OC(C)(C)C)OC(=O)C...              0.0
#
# ...
